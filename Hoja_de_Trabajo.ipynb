# %%
import pandas as pd
import numpy as np

# %%
## Traemos el dataset para transformar la informcion en Python
data_movies = pd.read_excel('D:/1 - Henry DS/PI01/movies_dataset.xlsx')
# Out:
# C:\Users\jorge\AppData\Local\Temp\ipykernel_4588\1844341823.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   data_movies = pd.read_excel('D:/1 - Henry DS/PI01/movies_dataset.xlsx')

# %%
## Revisamos las 5 primeras filas y validamos la cantidad de columnas que han subido
data_movies.head()
# Out:
#    adult                              belongs_to_collection  id_collection  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...        10194.0
# 1  False                                                NaN            NaN
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       119050.0
# 3  False                                                NaN            NaN
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...        96871.0
#
#                    name_collection             poster_path_collection  \
# 0            Toy Story Collection'  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg'
# 1                              NaN                                NaN
# 2       Grumpy Old Men Collection'  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg'
# 3                              NaN                                NaN
# 4  Father of the Bride Collection'  /nts4iOmNnq7GNicycMJ9pSAn204.jpg'
#
#              backdrop_path_collection    budget  \
# ...

# %%
### Función para extraer los datos anidados en columnas separadas, LA CUAL NO LOGRE OBTENER EL RESULTADO ESPERADO
# def extraer_datos_anidados(row):
#    if isinstance(row, dict):
#        return row.get('id'), row.get('name'), row.get('poster_path'), row.get('backdrop_path')
#    else:
#        return 'id', 'name', 'poster_path', 'backdrop_path'
#
### Aplicar la función a la columna "belongs_to_collection" y obtener las columnas separadas
# data_movies[['id', 'name', 'poster_path', 'backdrop_path']] = data_movies['belongs_to_collection'].apply(extraer_datos_anidados).apply(pd.Series)
#
### Imprimir el DataFrame actualizado
# print(data_movies)

# %%
## Nombre de cada columna en el dataset
print(data_movies.columns)
# Out:
# Index(['adult', 'belongs_to_collection', 'id_collection', 'name_collection',
#        'poster_path_collection', 'backdrop_path_collection', 'budget',
#        'genres', 'id_genero', 'name_genero', 'id_genero_1', 'name_genero_1',
#        'id_genero_2', 'name_genero_2', 'homepage', 'id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
## Miramos la informacion de la columna revenue
print(data_movies['revenue'])
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45461            0.0
# 45462            0.0
# 45463            0.0
# 45464            0.0
# 45465            0.0
# Name: revenue, Length: 45466, dtype: float64

# %%
## Validar cuantos nulos tenemos en la columna revenue
cuantos_nulos = data_movies['revenue'].isnull().sum()
print("Cantidad de valores nulos en la columna 'revenue':", cuantos_nulos)
# Out:
# Cantidad de valores nulos en la columna 'revenue': 6

# %%
## Saber cuales son los valores nulos que tenemos
cuales_son_los_nulos = data_movies[data_movies['revenue'].isnull()]
print(cuales_son_los_nulos)
# Out:
#                                                    adult  \
# 19729                                              False
# 19730                                 - Written by Ørnås
# 29502                                              False
# 29503  Rune Balot goes to a casino connected to the O...
# 35586                                              False
# 35587  Avalanche Sharks tells the story of a bikini c...
#
#                                    belongs_to_collection  id_collection  \
# 19729                                                NaN            NaN
# 19730                                           0.065736            0.0
# 29502  {'id': 122661, 'name': 'Mardock Scramble Colle...       122661.0
# 29503                                           1.931659            1.0
# 35586                                                NaN            NaN
# 35587                                           2.185485            2.0
#
# ...

# %%
## llenamos los campos con cero
data_movies['revenue'].fillna(0, inplace=True)

# %%
## PAra saber cuantos campos tnemos con cero
cuantos_llenados_con_cero = len(data_movies[data_movies['revenue'] == 0])
print("Cantidad de valores llenados con cero:", cuantos_llenados_con_cero)
# Out:
# Cantidad de valores llenados con cero: 38058

# %%
## Miramos la informacion de la columna budget
print(data_movies['budget'])
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45466, dtype: object

# %%
## Validar cuantos nulos tenemos en la columna budget
cuantos_nulos_budget = data_movies['revenue'].isnull().sum()
print("Cantidad de valores nulos en la columna 'budget':", cuantos_nulos_budget)
# Cero nulos, OK
# Out:
# Cantidad de valores nulos en la columna 'budget': 0

# %%
## Miramos la informacion de la columna budget
print(data_movies['release_date'])
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45461          NaT
# 45462   2011-11-17
# 45463   2003-08-01
# 45464   1917-10-21
# 45465   2017-06-09
# Name: release_date, Length: 45466, dtype: datetime64[ns]

# %%
## Validar cuantos nulos tenemos en la columna release_date
cuantos_nulos_release_date = data_movies['release_date'].isnull().sum()
print("Cantidad de valores nulos en la columna 'release_date':", cuantos_nulos_release_date)
# Out:
# Cantidad de valores nulos en la columna 'release_date': 87

# %%
## Saber cuales son los valores nulos que tenemos
cuales_son_los_nulos_release_date = data_movies[data_movies['release_date'].isnull()]
print(cuales_son_los_nulos_release_date)
# Out:
#        adult belongs_to_collection  id_collection name_collection  \
# 711    False                   NaN            NaN             NaN
# 734    False                   NaN            NaN             NaN
# 3460   False                   NaN            NaN             NaN
# 3628   False                   NaN            NaN             NaN
# 5879   False                   NaN            NaN             NaN
# ...      ...                   ...            ...             ...
# 45148  False                   NaN            NaN             NaN
# 45203  False                   NaN            NaN             NaN
# 45338  False                   NaN            NaN             NaN
# 45410  False                   NaN            NaN             NaN
# 45461  False                   NaN            NaN             NaN
#
#       poster_path_collection backdrop_path_collection budget  \
# 711                      NaN                      NaN      0
# ...

# %%
## Para validar, miramos la informacion de la columna adult, la cual tiene todos los datos llenos con valor 'FALSE'
print(data_movies['adult'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: adult, Length: 45466, dtype: object

# %%
## Ahora si eliminamos las filas de release_date
data_movies.dropna(subset = ['release_date'], inplace = True)

# %%
## Validamos de nuevo cuantos nulos tenemos en la columna release_date
cuantos_nulos_release_date = data_movies['release_date'].isnull().sum()
print("Cantidad de valores nulos en la columna 'release_date':", cuantos_nulos_release_date)
# Out:
# Cantidad de valores nulos en la columna 'release_date': 0

# %%
## Y validamos cuantas filas han quedado, mirando la columna 'adult'
print(data_movies['adult'])
# Del total anterior 45.466, eliminamos 87 y nos han quedado 45.379
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45460    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: adult, Length: 45379, dtype: object

# %%
## Crearemos la columna release_year, para extraer el año de la fecha de estreno.
data_movies
# Out:
#        adult                              belongs_to_collection  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1      False                                                NaN
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3      False                                                NaN
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...      ...                                                ...
# 45460  False                                                NaN
# 45462  False                                                NaN
# 45463  False                                                NaN
# 45464  False                                                NaN
# 45465  False                                                NaN
#
#        id_collection                  name_collection  \
# 0            10194.0            Toy Story Collection'
# 1                NaN                              NaN
# ...

# %%
## Crear una nueva columna llamada release_year y extraer de alli el año

# Convertir la columna "release_date" en formato de fecha
data_movies['release_date'] = pd.to_datetime(data_movies['release_date'])

# Extraer el año y crear la nueva columna "release_year"
data_movies['release_year'] = data_movies['release_date'].dt.year

# %%
data_movies.head()
# Out:
#    adult                              belongs_to_collection  id_collection  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...        10194.0
# 1  False                                                NaN            NaN
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       119050.0
# 3  False                                                NaN            NaN
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...        96871.0
#
#                    name_collection             poster_path_collection  \
# 0            Toy Story Collection'  /7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg'
# 1                              NaN                                NaN
# 2       Grumpy Old Men Collection'  /nLvUdqgPgm3F85NMCii9gVFUcet.jpg'
# 3                              NaN                                NaN
# 4  Father of the Bride Collection'  /nts4iOmNnq7GNicycMJ9pSAn204.jpg'
#
#              backdrop_path_collection    budget  \
# ...

# %%
data_movies # Ok, Ya tenemos 35 Columnas
# Out:
#        adult                              belongs_to_collection  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1      False                                                NaN
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3      False                                                NaN
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...      ...                                                ...
# 45460  False                                                NaN
# 45462  False                                                NaN
# 45463  False                                                NaN
# 45464  False                                                NaN
# 45465  False                                                NaN
#
#        id_collection                  name_collection  \
# 0            10194.0            Toy Story Collection'
# 1                NaN                              NaN
# ...

# %%
## Vamos a crear la columna return dividiendo los campo revenue / Budget, dejando en ceros los valores que no tienen dato
# Función para realizar división con manejo de división por cero
def calculate_return(row):
    revenue = pd.to_numeric(row['revenue'], errors='coerce')
    budget = pd.to_numeric(row['budget'], errors='coerce')
    
    if budget != 0:
        return revenue / budget
    else:
        return 0

# Rellenamos los valores que no tienen dato con cero
data_movies_filled = data_movies.fillna(0)

# Calculamos return, dividiendo revenue / budget
data_movies_filled['return'] = data_movies_filled.apply(calculate_return, axis=1)

# Imprimimos el DataFrame
print(data_movies_filled)
# Out:
#        adult                              belongs_to_collection  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1      False                                                  0
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3      False                                                  0
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...      ...                                                ...
# 45460  False                                                  0
# 45462  False                                                  0
# 45463  False                                                  0
# 45464  False                                                  0
# 45465  False                                                  0
#
#        id_collection                  name_collection  \
# 0            10194.0            Toy Story Collection'
# 1                0.0                                0
# ...

# %%
## Miramos cuantas columnas tiene data_movies
print(data_movies.columns)
# Out:
# Index(['adult', 'belongs_to_collection', 'id_collection', 'name_collection',
#        'poster_path_collection', 'backdrop_path_collection', 'budget',
#        'genres', 'id_genero', 'name_genero', 'id_genero_1', 'name_genero_1',
#        'id_genero_2', 'name_genero_2', 'homepage', 'id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count',
#        'release_year'],
#       dtype='object')

# %%
## Miramos cuantas columnas tiene data_movies_filled
print(data_movies_filled.columns)
# Out:
# Index(['adult', 'belongs_to_collection', 'id_collection', 'name_collection',
#        'poster_path_collection', 'backdrop_path_collection', 'budget',
#        'genres', 'id_genero', 'name_genero', 'id_genero_1', 'name_genero_1',
#        'id_genero_2', 'name_genero_2', 'homepage', 'id', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count',
#        'release_year', 'return'],
#       dtype='object')

# %%
## Cuantas columnas tenemos
data_movies_filled.shape[1]
# Out:
# 36

# %%
## Miramos los valores que estan con cifras calculadas en return
print(data_movies_filled[data_movies_filled['return'] > 0]['return'])
# Out:
# 0        12.451801
# 1         4.043035
# 3         5.090760
# 5         3.123947
# 8         1.838576
#            ...
# 45250     1.583333
# 45399     0.000004
# 45409     1.660765
# 45412     0.634397
# 45422     0.282600
# Name: return, Length: 5381, dtype: float64

# %%
## Eliminamos las columnas que no serán utilizadas, 'video','imdb_id','adult','original_title','poster_path' y 'homepage'.
columns_to_drop = ['video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage']
data_movies_filled.drop(columns=columns_to_drop, inplace=True)
print(data_movies_filled)
# Out:
#                                    belongs_to_collection  id_collection  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...        10194.0
# 1                                                      0            0.0
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...       119050.0
# 3                                                      0            0.0
# 4      {'id': 96871, 'name': 'Father of the Bride Col...        96871.0
# ...                                                  ...            ...
# 45460                                                  0            0.0
# 45462                                                  0            0.0
# 45463                                                  0            0.0
# 45464                                                  0            0.0
# 45465                                                  0            0.0
#
#                        name_collection             poster_path_collection  \
# ...

# %%
## Que columnas quedaron
print(data_movies_filled.columns)
# Out:
# Index(['belongs_to_collection', 'id_collection', 'name_collection',
#        'poster_path_collection', 'backdrop_path_collection', 'budget',
#        'genres', 'id_genero', 'name_genero', 'id_genero_1', 'name_genero_1',
#        'id_genero_2', 'name_genero_2', 'id', 'original_language', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'vote_average', 'vote_count', 'release_year',
#        'return'],
#       dtype='object')

# %%
## Cuantas columnas tenemos
data_movies_filled.shape[1]
# Out:
# 30
